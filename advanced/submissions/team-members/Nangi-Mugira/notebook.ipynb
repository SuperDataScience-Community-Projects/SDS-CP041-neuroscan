# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential

# %%
# Opening a zip file
from zipfile import ZipFile
with ZipFile('Data/archive.zip', 'r') as zip_ref:
    zip_ref.extractall('archive')

# %%
# Data paths
yes_data = 'Data/archive/brain_tumor_dataset/yes'
no_data = 'Data/archive/brain_tumor_dataset/no'

# %%
# Inspect number of images in each category
import os
num_yes = len(os.listdir(yes_data))
num_no = len(os.listdir(no_data))
print(f"Number of 'yes' images: {num_yes}")
print(f"Number of 'no' images: {num_no}")
# Out:
# Number of 'yes' images: 155
# Number of 'no' images: 98

# %%
import os, random, shutil

YES_DIR = r"Data/archive/brain_tumor_dataset/yes"      
NO_DIR  = r"Data/archive/brain_tumor_dataset/no"     
OUT_DIR = r"Data/archive/brain_tumor_just_split"   

random.seed(42)
os.makedirs(os.path.join(OUT_DIR, "yes"), exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "no"), exist_ok=True)

# Get all images
yes_images = [f for f in os.listdir(YES_DIR) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp','.tif','.tiff','.gif'))]
no_images  = [f for f in os.listdir(NO_DIR)  if f.lower().endswith(('.png','.jpg','.jpeg','.bmp','.tif','.tiff','.gif'))]

# Find equal count
n = min(len(yes_images), len(no_images))
print(f"Using {n} images from each class.")

# Randomly sample equal subsets
yes_subset = random.sample(yes_images, n)
no_subset  = random.sample(no_images,  n)

# Copy to new balanced folder
for f in yes_subset:
    shutil.copy2(os.path.join(YES_DIR, f), os.path.join(OUT_DIR, "yes", f))
for f in no_subset:
    shutil.copy2(os.path.join(NO_DIR, f), os.path.join(OUT_DIR, "no", f))

print("Balanced dataset created here:", OUT_DIR)
# Out:
# Using 98 images from each class.
# Balanced dataset created here: Data/archive/brain_tumor_just_split

# %%
yes_data = 'Data/archive/brain_tumor_just_split/yes'
no_data = 'Data/archive/brain_tumor_just_split/no'


num_yes = len(os.listdir(yes_data))
num_no = len(os.listdir(no_data))
print(f"Number of 'yes' images: {num_yes}")
print(f"Number of 'no' images: {num_no}")
# Out:
# Number of 'yes' images: 98
# Number of 'no' images: 98

# %%
import math

SRC_DIR = r"Data/archive/brain_tumor_just_split"   # contains balanced_data/yes and balanced_data/no
OUT_DIR = r"Data/archive/brain_tumor_prepped"
SPLIT = (0.70, 0.15, 0.15)  # train, val, test ratios

random.seed(42)
CLASSES = ["yes", "no"]
EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tif", ".tiff")

# make destination folders
for split in ["train", "val", "test"]:
    for cls in CLASSES:
        os.makedirs(os.path.join(OUT_DIR, split, cls), exist_ok=True)

# split and copy
for cls in CLASSES:
    src_folder = os.path.join(SRC_DIR, cls)
    files = [f for f in os.listdir(src_folder)
             if f.lower().endswith(EXTS) and os.path.isfile(os.path.join(src_folder, f))]
    random.shuffle(files)

    n = len(files)
    n_train = math.floor(SPLIT[0] * n)
    n_val   = math.floor(SPLIT[1] * n)

    train_files = files[:n_train]
    val_files   = files[n_train:n_train + n_val]
    test_files  = files[n_train + n_val:]

    for f in train_files:
        shutil.copy2(os.path.join(src_folder, f), os.path.join(OUT_DIR, "train", cls, f))
    for f in val_files:
        shutil.copy2(os.path.join(src_folder, f), os.path.join(OUT_DIR, "val", cls, f))
    for f in test_files:
        shutil.copy2(os.path.join(src_folder, f), os.path.join(OUT_DIR, "test", cls, f))

    print(f"{cls}: total={n} → train={len(train_files)}, val={len(val_files)}, test={len(test_files)}")

print("Done! Your folders are ready at:", OUT_DIR)
# Out:
# yes: total=98 → train=68, val=14, test=16
# no: total=98 → train=68, val=14, test=16
# Done! Your folders are ready at: Data/archive/brain_tumor_prepped

# %%
# Preparing the data
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   rotation_range=20,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode="nearest"
                                )

train_set = train_datagen.flow_from_directory('Data/archive/brain_tumor_prepped/train',
                                                    target_size=(128, 128),
                                                    batch_size=32,
                                                    class_mode='binary',
                                                    shuffle=True
                                                    )
# Out:
# Found 136 images belonging to 2 classes.

# %%
# 
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('Data/archive/brain_tumor_prepped/test',
                                                  target_size=(128, 128),
                                                  batch_size=32,
                                                  class_mode='binary',
                                                  shuffle=False)
# Out:
# Found 32 images belonging to 2 classes.

# %%
# Initialize the CNN
cnn = tf.keras.models.Sequential()
# Step 1 - Convolution
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[128, 128, 3]))
# Step 2 - Pooling
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# Adding a second convolutional layer
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# Step 3 - Flattening
cnn.add(tf.keras.layers.Flatten())
# Step 4 - Full Connection
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
# Step 5 - Output Layer
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Out:
# c:\Users\User\anaconda3\envs\learn-env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the CNN
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training the CNN
cnn.fit(x=train_set, validation_data=test_set, epochs=30)
# Out:
# c:\Users\User\anaconda3\envs\learn-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5221 - loss: 0.8653 - val_accuracy: 0.5000 - val_loss: 0.6986
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 594ms/step - accuracy: 0.5956 - loss: 0.6394 - val_accuracy: 0.7188 - val_loss: 0.5972
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 639ms/step - accuracy: 0.6471 - loss: 0.6356 - val_accuracy: 0.7812 - val_loss: 0.5460
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 606ms/step - accuracy: 0.7647 - loss: 0.5578 - val_accuracy: 0.7812 - val_loss: 0.4607
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 622ms/step - accuracy: 0.7059 - loss: 0.5565 - val_accuracy: 0.7812 - val_loss: 0.5014
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 498ms/step - accuracy: 0.6544 - loss: 0.5766 - val_accuracy: 0.7812 - val_loss: 0.4334
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 522ms/step - accuracy: 0.7426 - loss: 0.5256 - val_accuracy: 0.7500 - val_loss: 0.4569
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - accuracy: 0.7500 - loss: 0.5437 - val_accuracy: 0.8125 - val_loss: 0.4118
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 494ms/step - accuracy: 0.7500 - loss: 0.5372 - val_accuracy: 0.8125 - val_loss: 0.4358
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 572ms/step - accuracy: 0.7500 - loss: 0.5316 - val_accuracy: 0.7812 - val_loss: 0.4449
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - accuracy: 0.7353 - loss: 0.5170 - val_accuracy: 0.8125 - val_loss: 0.4303
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - accuracy: 0.7206 - loss: 0.5314 - val_accuracy: 0.8125 - val_loss: 0.4474
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 522ms/step - accuracy: 0.7353 - loss: 0.5355 - val_accuracy: 0.8125 - val_loss: 0.4213
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 606ms/step - accuracy: 0.7132 - loss: 0.5435 - val_accuracy: 0.7812 - val_loss: 0.4548
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 542ms/step - accuracy: 0.7206 - loss: 0.5182 - val_accuracy: 0.8438 - val_loss: 0.4039
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.7794 - loss: 0.4902 - val_accuracy: 0.8438 - val_loss: 0.4045
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.7353 - loss: 0.4700 - val_accuracy: 0.8438 - val_loss: 0.3812
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 616ms/step - accuracy: 0.7426 - loss: 0.5292 - val_accuracy: 0.7188 - val_loss: 0.5999
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 547ms/step - accuracy: 0.6838 - loss: 0.6131 - val_accuracy: 0.7500 - val_loss: 0.5933
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - accuracy: 0.7941 - loss: 0.4741 - val_accuracy: 0.7500 - val_loss: 0.5111
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - accuracy: 0.7206 - loss: 0.5476 - val_accuracy: 0.7188 - val_loss: 0.4787
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 502ms/step - accuracy: 0.7426 - loss: 0.4782 - val_accuracy: 0.8438 - val_loss: 0.3826
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 639ms/step - accuracy: 0.7647 - loss: 0.5221 - val_accuracy: 0.7500 - val_loss: 0.5984
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 673ms/step - accuracy: 0.6765 - loss: 0.6061 - val_accuracy: 0.7812 - val_loss: 0.5467
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 607ms/step - accuracy: 0.7206 - loss: 0.5122 - val_accuracy: 0.7500 - val_loss: 0.4740
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - accuracy: 0.7206 - loss: 0.5553 - val_accuracy: 0.7500 - val_loss: 0.4818
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 549ms/step - accuracy: 0.7574 - loss: 0.4982 - val_accuracy: 0.6562 - val_loss: 0.6297
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 497ms/step - accuracy: 0.7353 - loss: 0.5148 - val_accuracy: 0.7812 - val_loss: 0.4345
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 495ms/step - accuracy: 0.7279 - loss: 0.5312 - val_accuracy: 0.7812 - val_loss: 0.4701
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 476ms/step - accuracy: 0.7574 - loss: 0.4594 - val_accuracy: 0.7812 - val_loss: 0.5090

# %%
cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 28800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,686,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,090,405 (42.31 MB)
#  Trainable params: 3,696,801 (14.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,393,604 (28.20 MB)

# %%
# evaluation
test_loss, test_acc = cnn.evaluate(test_set)
print('\nTest accuracy:', test_acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.7812 - loss: 0.5090
#
# Test accuracy: 0.78125

# %%
# confusion matrix and classification report
from sklearn.metrics import classification_report, confusion_matrix
y_pred = cnn.predict(test_set)
y_pred = (y_pred > 0.5).astype(int)
print(confusion_matrix(test_set.classes, y_pred))
print(classification_report(test_set.classes, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# [[ 9  7]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.72        16
#            1       0.70      1.00      0.82        16
#
#     accuracy                           0.78        32
#    macro avg       0.85      0.78      0.77        32
# weighted avg       0.85      0.78      0.77        32

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model

# %%
pretrained_model = ResNet50(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
for layer in pretrained_model.layers:
    layer.trainable = False
x = pretrained_model.output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
resnet_cnn = Model(inputs=pretrained_model.input, outputs=x)

# %%
resnet_cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
resnet_cnn.fit(x=train_set, validation_data=test_set, epochs=30)
# Out:
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5588 - loss: 1.0395 - val_accuracy: 0.4688 - val_loss: 0.8871
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4926 - loss: 0.8901 - val_accuracy: 0.5000 - val_loss: 1.0499
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5735 - loss: 0.7120 - val_accuracy: 0.5625 - val_loss: 0.6791
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5368 - loss: 0.7009 - val_accuracy: 0.5625 - val_loss: 0.6798
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.6985 - loss: 0.6205 - val_accuracy: 0.5000 - val_loss: 0.7387
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.5956 - loss: 0.6401 - val_accuracy: 0.5625 - val_loss: 0.7114
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6838 - loss: 0.6192 - val_accuracy: 0.5938 - val_loss: 0.6546
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6765 - loss: 0.6046 - val_accuracy: 0.6562 - val_loss: 0.6555
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.7353 - loss: 0.5759 - val_accuracy: 0.6562 - val_loss: 0.6222
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.6985 - loss: 0.5669 - val_accuracy: 0.6562 - val_loss: 0.6077
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6691 - loss: 0.5887 - val_accuracy: 0.6875 - val_loss: 0.6129
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7353 - loss: 0.5616 - val_accuracy: 0.6250 - val_loss: 0.5850
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.6691 - loss: 0.5726 - val_accuracy: 0.7188 - val_loss: 0.5780
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7206 - loss: 0.5466 - val_accuracy: 0.7500 - val_loss: 0.5927
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7132 - loss: 0.5665 - val_accuracy: 0.6250 - val_loss: 0.5552
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7353 - loss: 0.5531 - val_accuracy: 0.7500 - val_loss: 0.5768
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7500 - loss: 0.5542 - val_accuracy: 0.6875 - val_loss: 0.5304
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7206 - loss: 0.5346 - val_accuracy: 0.6562 - val_loss: 0.5286
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6912 - loss: 0.5785 - val_accuracy: 0.7188 - val_loss: 0.5359
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7868 - loss: 0.5039 - val_accuracy: 0.7188 - val_loss: 0.5244
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7353 - loss: 0.5454 - val_accuracy: 0.8125 - val_loss: 0.5278
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7647 - loss: 0.5135 - val_accuracy: 0.8438 - val_loss: 0.5086
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7132 - loss: 0.5648 - val_accuracy: 0.6562 - val_loss: 0.5294
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7059 - loss: 0.5271 - val_accuracy: 0.7500 - val_loss: 0.5598
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.5882 - loss: 0.7057 - val_accuracy: 0.7188 - val_loss: 0.5906
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7206 - loss: 0.5993 - val_accuracy: 0.6562 - val_loss: 0.5953
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6397 - loss: 0.6450 - val_accuracy: 0.5625 - val_loss: 0.7414
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6618 - loss: 0.6634 - val_accuracy: 0.7812 - val_loss: 0.5021
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6176 - loss: 0.6367 - val_accuracy: 0.6562 - val_loss: 0.5262
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7132 - loss: 0.5398 - val_accuracy: 0.7500 - val_loss: 0.5542

# %%
# Evaluation
test_loss, test_acc = resnet_cnn.evaluate(test_set)
print('\nTest accuracy with ResNet50:', test_acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7500 - loss: 0.5542
#
# Test accuracy with ResNet50: 0.75

# %%
# confusion matrix and classification report
from sklearn.metrics import classification_report, confusion_matrix
y_pred = resnet_cnn.predict(test_set)
y_pred = (y_pred > 0.5).astype(int)
print(confusion_matrix(test_set.classes, y_pred))
print(classification_report(test_set.classes, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# [[ 8  8]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67        16
#            1       0.67      1.00      0.80        16
#
#     accuracy                           0.75        32
#    macro avg       0.83      0.75      0.73        32
# weighted avg       0.83      0.75      0.73        32

# %%
# Save the CNN model
import tensorflow as tf

tf.keras.models.save_model(cnn, 'brain_tumor_classifier_cnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
